# %%
import numpy as np 
import copy
popul = np.random.randn(10, 2).tolist()
a = np.full((10,2),4)
b = np.full((10,2),-2)
popul = popul * a-b
def func(x,y):
#    return 20 + x**2+y**2-10*(np.cos(2*np.pi*x)+np.cos(2*np.pi*y))
    return x**2-2*x*y+6*y**2+x-y
def f_min(popul):
    return np.min([func(x,y) for x, y in popul])

# %%
#print(population[0:20][:])
f_min(popul)
#plot

_x= np.arange(-10.,10.,0.5)
_y= np.arange(-10.,10.,0.5)  
_x,_y=np.meshgrid(_x,_y)
_z= func(_x, _y)

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.view_init(62, 11)
ax.plot_surface(_x, _y, _z, cmap=cm.coolwarm,rstride=1, cstride=1, linewidth=0.5, antialiased=True, color='blue',alpha=0.8)
ax.plot_wireframe(_x, _y, _z, linewidth=0.5, antialiased=True, color='blue')

#plot
print(_x[1])
# Out:
# [-10.   -9.5  -9.   -8.5  -8.   -7.5  -7.   -6.5  -6.   -5.5  -5.   -4.5
#   -4.   -3.5  -3.   -2.5  -2.   -1.5  -1.   -0.5   0.    0.5   1.    1.5
#    2.    2.5   3.    3.5   4.    4.5   5.    5.5   6.    6.5   7.    7.5
#    8.    8.5   9.    9.5]

# %%
k=0
while k<100:
    order = np.argsort([func(*item) for item in popul])
    x_ord = abs(np.random.normal(0, 2, 10)).astype(int)
    y_ord = abs(np.random.normal(0, 2, 10)).astype(int)
    x_ord = x_ord%10
    y_ord = y_ord%10
    newpop = np.copy(popul)
    i=0
    for x1, y1 in zip(x_ord, y_ord):   #create new population
        newpop[i][0]=popul[order[x1]][0]
        newpop[i][1]=popul[order[y1]][1]
        i+=1
    popul = np.copy(newpop)
    for i in range(0,10):
        if np.random.rand(1,1)>0.8:
            if np.random.rand(1,1)>0.5:
                if np.random.rand(1,1)<0.5:
                    popul[i][0]+=0.05/abs(np.random.rand(1, 1))
                else:
                    popul[i][0]-=0.05/abs(np.random.rand(1, 1))
            else:
                if np.random.rand(1,1)<0.5:
                    popul[i][1]+=0.05/abs(np.random.rand(1, 1))
                else:
                    popul[i][1]-=0.05/abs(np.random.rand(1, 1))
    #draw
    plt.plot(popul[:,0], popul[:,1], func(popul[:,0], popul[:,1]), 'ro')
    plt.draw()
    #draw  
    plt.pause(0.2)
    k+=1
    print("min ",f_min(popul))
# Out:
# min  8.000345995044437
# min  8.000345995044437
# min  7.499486118858163
# min  7.499486118858163
# min  6.573162041909512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-b152eb9c25dd> in <module>
#      29     plt.draw()
#      30     #draw
# ---> 31     plt.pause(0.2)
#      32     k+=1
#      33     print("min ",f_min(popul))
#
# /usr/lib/python3.7/site-packages/matplotlib/pyplot.py in pause(interval)
#     293             canvas.draw_idle()
#     294         show(block=False)
# --> 295         canvas.start_event_loop(interval)
#     296     else:
#     297         time.sleep(interval)
#
# /usr/lib/python3.7/site-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2250         while self._looping and counter * timestep < timeout:
#    2251             self.flush_events()
# -> 2252             time.sleep(timestep)
#    2253             counter += 1
#    2254
#
# KeyboardInterrupt:

# %%
x_ord%100
# Out:
# array([0, 1, 0, 0, 1, 0, 0, 0, 2, 0])
